# %% [markdown]
# # business understanding

# %%
# optimize flights to reduce flight delays

# %% [markdown]
# # data understanding

# %%
# EDA
import pandas as pd

df = pd.read_csv("/content/combined.csv")
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  1987     11          28          6   2042.0        2025
# 1           1  1987     10          22          4   1805.0        1800
# 2           2  1987     11          19          4    657.0         655
# 3           3  1987     11          23          1   1848.0        1835
# 4           4  1987     11          25          3    703.0         655
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2105.0        2053            PI  ...     NaN     NaN          0
# 1   1933.0        1905            HP  ...     NaN     NaN          0
# 2    821.0         804            PI  ...     NaN     NaN          0
# 3   1944.0        1920            DL  ...     NaN     NaN          0
# 4    828.0         821            AA  ...     NaN     NaN          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df.shape # size of dataset
# Out:
# (22000, 30)

# %%
df.columns # list of columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.info() # describe datatyeps , value anf columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         22000 non-null  int64
#  1   Year               22000 non-null  int64
#  2   Month              22000 non-null  int64
#  3   DayofMonth         22000 non-null  int64
#  4   DayOfWeek          22000 non-null  int64
#  5   DepTime            22000 non-null  float64
#  6   CRSDepTime         22000 non-null  int64
#  7   ArrTime            21919 non-null  float64
#  8   CRSArrTime         22000 non-null  int64
#  9   UniqueCarrier      22000 non-null  object
#  10  FlightNum          22000 non-null  int64
#  11  TailNum            14000 non-null  object
#  12  ActualElapsedTime  21917 non-null  float64
#  13  CRSElapsedTime     22000 non-null  float64
#  14  AirTime            13950 non-null  float64
#  15  ArrDelay           21917 non-null  float64
# ...

# %%
df.describe() # statistical summary
# Out:
#          Unnamed: 0          Year         Month    DayofMonth     DayOfWeek  \
# count  22000.000000  22000.000000  22000.000000  22000.000000  22000.000000
# mean   10999.500000   1997.500000      6.726591     15.919591      4.017909
# std     6350.997297      6.344433      3.527147      8.717935      1.981814
# min        0.000000   1987.000000      1.000000      1.000000      1.000000
# 25%     5499.750000   1992.000000      4.000000      8.000000      2.000000
# 50%    10999.500000   1997.500000      7.000000     16.000000      4.000000
# 75%    16499.250000   2003.000000     10.000000     23.000000      6.000000
# max    21999.000000   2008.000000     12.000000     31.000000      7.000000
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  22000.000000  22000.000000  21919.000000  22000.000000  22000.000000
# mean    1458.535955   1422.683364   1581.473014   1580.288636   1229.434182
# ...

# %%
df.select_dtypes(include=['object']).columns # categorical columns
# Out:
# Index(['UniqueCarrier', 'TailNum', 'Origin', 'Dest'], dtype='object')

# %%
df.TailNum.unique()
# Out:
# array([nan, 'N869AA', 'N912VJ', ..., 'N103US', 'N234WN', 'N720WN'],
#       dtype=object)

# %%
# hypothesis

# %% [markdown]
# # data processing

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Year                     0
# Month                    0
# DayofMonth               0
# DayOfWeek                0
# DepTime                  0
# CRSDepTime               0
# ArrTime                 81
# CRSArrTime               0
# UniqueCarrier            0
# FlightNum                0
# TailNum               8000
# ActualElapsedTime       83
# CRSElapsedTime           0
# AirTime               8050
# ArrDelay                83
# DepDelay                 0
# Origin                   0
# Dest                     0
# Distance                38
# TaxiIn                8004
# TaxiOut               8000
# Cancelled                0
# CancellationCode     22000
# Diverted                 0
# CarrierDelay         16893
# WeatherDelay         16893
# NASDelay             16893
# SecurityDelay        16893
# LateAircraftDelay    16893
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'CancellationCode'], axis = 1, inplace = True)

# %%
df.isnull()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      False  False       False      False    False       False    False
# 1      False  False       False      False    False       False    False
# 2      False  False       False      False    False       False    False
# 3      False  False       False      False    False       False    False
# 4      False  False       False      False    False       False    False
# ...      ...    ...         ...        ...      ...         ...      ...
# 21995  False  False       False      False    False       False    False
# 21996  False  False       False      False    False       False    False
# 21997  False  False       False      False    False       False    False
# 21998  False  False       False      False    False       False    False
# 21999  False  False       False      False    False       False    False
#
#        CRSArrTime  UniqueCarrier  FlightNum  ...  Distance  TaxiIn  TaxiOut  \
# ...

# %%
import seaborn as sns
sns.heatmap(df.isnull(), cbar = False)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (22000, 28)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     11          28          6   2042.0        2025   2105.0
# 1  1987     10          22          4   1805.0        1800   1933.0
# 2  1987     11          19          4    657.0         655    821.0
# 3  1987     11          23          1   1848.0        1835   1944.0
# 4  1987     11          25          3    703.0         655    828.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... Distance  TaxiIn  TaxiOut  \
# 0        2053            PI        801  ...     21.0     NaN      NaN
# 1        1905            HP        226  ...    370.0     NaN      NaN
# 2         804            PI         79  ...    200.0     NaN      NaN
# 3        1920            DL        653  ...    641.0     NaN      NaN
# 4         821            AA       2277  ...    371.0     NaN      NaN
#
#    Cancelled  Diverted  CarrierDelay WeatherDelay NASDelay  SecurityDelay  \
# ...

# %%
filtered_df = df[
    df[['CarrierDelay','WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']].
                 apply(
                     lambda row:
                     all(
                         x not in [None, ''] and pd.notna(x) for x in row)
                     , axis = 1)
                 ]

# %%
filtered_df.shape
# Out:
# (5107, 28)

# %%
filtered_df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# DayofMonth            0
# DayOfWeek             0
# DepTime               0
# CRSDepTime            0
# ArrTime              12
# CRSArrTime            0
# UniqueCarrier         0
# FlightNum             0
# TailNum               0
# ActualElapsedTime    12
# CRSElapsedTime        0
# AirTime              12
# ArrDelay             12
# DepDelay              0
# Origin                0
# Dest                  0
# Distance              0
# TaxiIn                0
# TaxiOut               0
# Cancelled             0
# Diverted              0
# CarrierDelay          0
# WeatherDelay          0
# NASDelay              0
# SecurityDelay         0
# LateAircraftDelay     0
# dtype: int64

# %%
filtered_df.dropna(inplace = True, axis =0)
# Out:
# <ipython-input-24-a3ab54a75896>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.dropna(inplace = True, axis =0)

# %%
filtered_df.shape
# Out:
# (5095, 28)

# %%
filtered_df.head()
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 16003  2003     10          14          2   1612.0        1600   1927.0
# 16004  2003     12           5          5   1445.0        1430   1537.0
# 16005  2003      6          18          3   1718.0        1715   1847.0
# 16008  2003      7           9          3   1354.0        1325   1548.0
# 16009  2003     12          20          6   1627.0        1620   1905.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... Distance  TaxiIn  TaxiOut  \
# 16003        1911            UA       1278  ...    678.0    10.0     21.0
# 16004        1530            WN         33  ...    239.0     2.0      5.0
# 16005        1857            CO        445  ...    416.0     3.0     24.0
# 16008        1512            MQ       4006  ...    137.0     3.0     27.0
# 16009        1905            WN       2312  ...    588.0     5.0      8.0
#
#        Cancelled  Diverted  CarrierDelay WeatherDelay NASDelay  SecurityDelay  \
# ...

# %%
filtered_df.LateAircraftDelay.value_counts()
# Out:
# LateAircraftDelay
# 0.0      3672
# 20.0       40
# 16.0       39
# 15.0       39
# 14.0       38
#          ...
# 165.0       1
# 132.0       1
# 215.0       1
# 235.0       1
# 184.0       1
# Name: count, Length: 180, dtype: int64

# %%
df.drop(['WeatherDelay', 'SecurityDelay'], axis = 1, inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'Diverted', 'CarrierDelay', 'NASDelay',
#        'LateAircraftDelay'],
#       dtype='object')

# %%
df.TailNum.value_counts()
# Out:
# TailNum
# N506      13
# N684      12
# N350UA    12
# N527      11
# N325      11
#           ..
# N354SW     1
# N477WN     1
# N923AT     1
# N69523     1
# N14106     1
# Name: count, Length: 6565, dtype: int64

# %%
import pandas as pd

# Load your data
df = pd.read_csv('combined.csv')

# Clean and extract departure hour from DepTime (e.g., 1830 → 18)
df = df[df['DepTime'].notna()]
df['DepTime'] = df['DepTime'].astype(int)
df['DepHour'] = df['DepTime'].astype(str).str.zfill(4).str[:2].astype(int)

# Define delayed flights (more than 15 minutes delay)
df['IsDelayed'] = df['ArrDelay'] > 15

# Calculate overall delay rate
overall_delay_rate = df['IsDelayed'].mean()

# Filter for flights departing between 6 PM (18) and 10 PM (21)
evening_flights = df[(df['DepHour'] >= 18) & (df['DepHour'] <= 21)]
evening_delay_rate = evening_flights['IsDelayed'].mean()

# Calculate percentage increase
increase = ((evening_delay_rate - overall_delay_rate) / overall_delay_rate) * 100

# Print result
print(f"Evening delay rate: {evening_delay_rate:.2%}")
print(f"Overall delay rate: {overall_delay_rate:.2%}")
print(f"Increase in delay: {increase:.2f}%")
# Out:
# Evening delay rate: 49.63%
# Overall delay rate: 40.20%
# Increase in delay: 23.44%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("combined.csv")  # Use the correct path if different

# Set the style for plots
sns.set(style="whitegrid")
plt.figure(figsize=(16, 12))

# 1. Heatmap: Average Arrival Delay by Day of Week and Month
heatmap_data = df.pivot_table(values='ArrDelay', index='DayOfWeek', columns='Month', aggfunc='mean')
plt.subplot(3, 1, 1)
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="coolwarm")
plt.title('Average Arrival Delay by Day of Week and Month')

# 2. Bar Chart: Average Arrival Delay by Airline
plt.subplot(3, 1, 2)
carrier_delay = df.groupby('UniqueCarrier')['ArrDelay'].mean().sort_values()
sns.barplot(x=carrier_delay.index, y=carrier_delay.values, palette="viridis")
plt.ylabel('Average Arrival Delay')
plt.xlabel('Airline')
plt.title('Average Arrival Delay by Airline')

# 3. Box Plot: Departure Delay Distribution by Month
plt.subplot(3, 1, 3)
sns.boxplot(x='Month', y='DepDelay', data=df)
plt.title('Departure Delay Distribution by Month')
plt.ylabel('Departure Delay (minutes)')
plt.xlabel('Month')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-1c96e2b73e71>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=carrier_delay.index, y=carrier_delay.values, palette="viridis")

# %%
# data analytics
